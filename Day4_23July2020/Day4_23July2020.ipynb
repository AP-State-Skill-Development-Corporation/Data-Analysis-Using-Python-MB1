# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/AP-State-Skill-Development-Corporation/Data-Analysis-Using-Python-MB1/master/Day4_23July2020/Advertising.csv")

# %%
df.head()
# Out:
#    Unnamed: 0     TV  radio  newspaper  sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
df1 = pd.read_csv('Advertising.csv', index_col = 0)
df1.head()
# Out:
#       TV  radio  newspaper  sales
# 1  230.1   37.8       69.2   22.1
# 2   44.5   39.3       45.1   10.4
# 3   17.2   45.9       69.3    9.3
# 4  151.5   41.3       58.5   18.5
# 5  180.8   10.8       58.4   12.9

# %%
len(dir(pd))
# Out:
# 139

# %%
len(dir(df))
# Out:
# 454

# %%
df1.shape
# Out:
# (200, 4)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 200 entries, 1 to 200
# Data columns (total 4 columns):
# TV           200 non-null float64
# radio        200 non-null float64
# newspaper    200 non-null float64
# sales        200 non-null float64
# dtypes: float64(4)
# memory usage: 7.8 KB

# %%
df1.describe()
# Out:
#                TV       radio   newspaper       sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   14.022500
# std     85.854236   14.846809   21.778621    5.217457
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   10.375000
# 50%    149.750000   22.900000   25.750000   12.900000
# 75%    218.825000   36.525000   45.100000   17.400000
# max    296.400000   49.600000  114.000000   27.000000

# %%
df1
# Out:
#         TV  radio  newspaper  sales
# 1    230.1   37.8       69.2   22.1
# 2     44.5   39.3       45.1   10.4
# 3     17.2   45.9       69.3    9.3
# 4    151.5   41.3       58.5   18.5
# 5    180.8   10.8       58.4   12.9
# 6      8.7   48.9       75.0    7.2
# 7     57.5   32.8       23.5   11.8
# 8    120.2   19.6       11.6   13.2
# 9      8.6    2.1        1.0    4.8
# 10   199.8    2.6       21.2   10.6
# 11    66.1    5.8       24.2    8.6
# 12   214.7   24.0        4.0   17.4
# 13    23.8   35.1       65.9    9.2
# 14    97.5    7.6        7.2    9.7
# 15   204.1   32.9       46.0   19.0
# 16   195.4   47.7       52.9   22.4
# 17    67.8   36.6      114.0   12.5
# 18   281.4   39.6       55.8   24.4
# 19    69.2   20.5       18.3   11.3
# 20   147.3   23.9       19.1   14.6
# 21   218.4   27.7       53.4   18.0
# 22   237.4    5.1       23.5   12.5
# 23    13.2   15.9       49.6    5.6
# 24   228.3   16.9       26.2   15.5
# 25    62.3   12.6       18.3    9.7
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
mean = df1['TV'].mean()

std = df1['TV'].std()

# %%
mean, std
# Out:
# (147.0425, 85.8542363149081)

# %%
col200 = (231.1 - mean) / std

col200
# Out:
# 0.9790722462626331

# %% [markdown]
# pip install package_name

# %%
pip install sklearn

# %%
from sklearn.preprocessing import scale

# %%
df1.head()
# Out:
#       TV  radio  newspaper  sales
# 1  230.1   37.8       69.2   22.1
# 2   44.5   39.3       45.1   10.4
# 3   17.2   45.9       69.3    9.3
# 4  151.5   41.3       58.5   18.5
# 5  180.8   10.8       58.4   12.9

# %%
scl = scale(df1)

print(scl)
# Out:
# [[ 9.69852266e-01  9.81522472e-01  1.77894547e+00  1.55205313e+00]
#  [-1.19737623e+00  1.08280781e+00  6.69578760e-01 -6.96046111e-01]
#  [-1.51615499e+00  1.52846331e+00  1.78354865e+00 -9.07405869e-01]
#  [ 5.20496822e-02  1.21785493e+00  1.28640506e+00  8.60330287e-01]
#  [ 3.94182198e-01 -8.41613655e-01  1.28180188e+00 -2.15683025e-01]
#  [-1.61540845e+00  1.73103399e+00  2.04592999e+00 -1.31091086e+00]
#  [-1.04557682e+00  6.43904671e-01 -3.24708413e-01 -4.27042783e-01]
#  [-3.13436589e-01 -2.47406325e-01 -8.72486994e-01 -1.58039455e-01]
#  [-1.61657614e+00 -1.42906863e+00 -1.36042422e+00 -1.77205942e+00]
#  [ 6.16042873e-01 -1.39530685e+00 -4.30581584e-01 -6.57617064e-01]
#  [-9.45155670e-01 -1.17923146e+00 -2.92486143e-01 -1.04190753e+00]
#  [ 7.90028350e-01  4.96973404e-02 -1.22232878e+00  6.48970529e-01]
#  [-1.43908760e+00  7.99208859e-01  1.62704048e+00 -9.26620392e-01]
#  [-5.78501712e-01 -1.05768905e+00 -1.07502697e+00 -8.30547775e-01]
# ...

# %%
scl.mean(axis = 0).round(decimals=3)
# Out:
# array([ 0., -0.,  0., -0.])

# %%
scl.std(axis = 0).round(decimals=3)
# Out:
# array([1., 1., 1., 1.])

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np 
stock1 = np.array([5, 6, 5.5, 28, 1, 5, 5.5, 6.5, 5])
stock2 = np.array([5, 6, 5.5, 5.2, 5.5, 5, 5.5, 6.5, 5])

# %%
stock1.mean(), stock2.mean()
# Out:
# (7.5, 5.466666666666667)

# %%
np.median(stock1), np.median(stock2)
# Out:
# (5.5, 5.5)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from sklearn.preprocessing import RobustScaler

# %%
rsc = RobustScaler()

rsc.fit_transform(df1)
# Out:
# array([[ 5.56247837e-01,  5.61205273e-01,  1.34312210e+00,
#          1.30960854e+00],
#        [-7.28625822e-01,  6.17702448e-01,  5.98145286e-01,
#         -3.55871886e-01],
#        [-9.17618553e-01,  8.66290019e-01,  1.34621329e+00,
#         -5.12455516e-01],
#        [ 1.21149187e-02,  6.93032015e-01,  1.01236476e+00,
#          7.97153025e-01],
#        [ 2.14953271e-01, -4.55743879e-01,  1.00927357e+00,
#          0.00000000e+00],
#        [-9.76462444e-01,  9.79284369e-01,  1.52241113e+00,
#         -8.11387900e-01],
#        [-6.38629283e-01,  3.72881356e-01, -6.95517774e-02,
#         -1.56583630e-01],
#        [-2.04569055e-01, -1.24293785e-01, -4.37403400e-01,
#          4.27046263e-02],
#        [-9.77154725e-01, -7.83427495e-01, -7.65069552e-01,
#         -1.15302491e+00],
#        [ 3.46486674e-01, -7.64595104e-01, -1.40649150e-01,
#         -3.27402135e-01],
#        [-5.79093112e-01, -6.44067797e-01, -4.79134467e-02,
#         -6.12099644e-01],
# ...

# %%
arr = np.array([1, 0, 500, 501])
arr2 = arr/1000

print(arr, arr2)
# Out:
# [  1   0 500 501] [0.001 0.    0.5   0.501]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x = df1['TV'].iloc[0]

minmax = (x - df1['TV'].min()) / (df1['TV'].max() - df1['TV'].min())

x, minmax
# Out:
# (230.1, 0.7757862698681096)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
obj = MinMaxScaler()


obj.fit_transform(df1)
# Out:
# array([[0.77578627, 0.76209677, 0.60598065, 0.80708661],
#        [0.1481231 , 0.79233871, 0.39401935, 0.34645669],
#        [0.0557998 , 0.92540323, 0.60686016, 0.30314961],
#        [0.50997633, 0.83266129, 0.51187335, 0.66535433],
#        [0.60906324, 0.21774194, 0.51099384, 0.44488189],
#        [0.02705445, 0.9858871 , 0.65699208, 0.22047244],
#        [0.19208657, 0.66129032, 0.20404573, 0.4015748 ],
#        [0.4041258 , 0.39516129, 0.09938434, 0.45669291],
#        [0.02671627, 0.04233871, 0.00615655, 0.12598425],
#        [0.67331755, 0.05241935, 0.18381706, 0.35433071],
#        [0.2211701 , 0.11693548, 0.21020229, 0.27559055],
#        [0.72370646, 0.48387097, 0.03254178, 0.62204724],
#        [0.07811972, 0.70766129, 0.5769569 , 0.2992126 ],
#        [0.32735881, 0.15322581, 0.06068602, 0.31889764],
#        [0.68785932, 0.66330645, 0.40193492, 0.68503937],
#        [0.65843761, 0.96169355, 0.46262093, 0.81889764],
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from sklearn.preprocessing import Normalizer

# %%
nor = Normalizer()


nor.fit_transform(df1)
# Out:
# array([[0.94211621, 0.15476746, 0.28333091, 0.09048574],
#        [0.59113524, 0.52205877, 0.59910561, 0.13815296],
#        [0.20142628, 0.53752711, 0.81156054, 0.10891072],
#        [0.89863215, 0.24497365, 0.34699657, 0.10973396],
#        [0.94788063, 0.05662119, 0.30617383, 0.06763086],
#        [0.09640672, 0.54187225, 0.83109241, 0.07978487],
#        [0.80725471, 0.46048617, 0.32992149, 0.16566271],
#        [0.97684844, 0.15928643, 0.09427156, 0.10727454],
#        [0.84982063, 0.20751434, 0.09881635, 0.47431849],
#        [0.99295394, 0.01292132, 0.10535848, 0.05267924],
#        [0.92901149, 0.08151689, 0.34012221, 0.12086988],
#        [0.99043367, 0.11071452, 0.01845242, 0.08026803],
#        [0.30163094, 0.44484227, 0.83518819, 0.11659683],
#        [0.98945567, 0.0771268 , 0.0730675 , 0.09843815],
#        [0.95983344, 0.15472082, 0.21632699, 0.08935245],
#        [0.93412001, 0.22803237, 0.25289124, 0.10708438],
# ...

# %%
sq = df1['TV'] ** 2

l = sq.sum() ** 0.5

230.1/l
# Out:
# 0.09561706240078917

# %%
arr = np.array([[1, 2, 3, np.nan], [2, 5, np.nan, 5], 
               [2, np.nan, 2, 3]])

# %% [markdown]
# 1. Mean()
# 2. Median()
# 3. most frequent value
# 4. constant

# %%
from sklearn.impute import SimpleImputer

# %%
imp = SimpleImputer(strategy='median')

# %%
imp.fit_transform(arr)
# Out:
# array([[1. , 2. , 3. , 4. ],
#        [2. , 5. , 2.5, 5. ],
#        [2. , 3.5, 2. , 3. ]])

# %%
imp = SimpleImputer(strategy='mean')
imp.fit_transform(arr)
# Out:
# array([[1. , 2. , 3. , 4. ],
#        [2. , 5. , 2.5, 5. ],
#        [2. , 3.5, 2. , 3. ]])

# %%
arr
# Out:
# array([[ 1.,  2.,  3., nan],
#        [ 2.,  5., nan,  5.],
#        [ 2., nan,  2.,  3.]])

# %%
imp = SimpleImputer(strategy='most_frequent')
imp.fit_transform(arr)
# Out:
# array([[1., 2., 3., 3.],
#        [2., 5., 3., 5.],
#        [2., 2., 2., 3.],
#        [1., 2., 3., 4.]])

# %%
help(imp)
# Out:
# Help on SimpleImputer in module sklearn.impute object:
#
# class SimpleImputer(sklearn.base.BaseEstimator, sklearn.base.TransformerMixin)
#  |  SimpleImputer(missing_values=nan, strategy='mean', fill_value=None, verbose=0, copy=True)
#  |
#  |  Imputation transformer for completing missing values.
#  |
#  |  Read more in the :ref:`User Guide <impute>`.
#  |
#  |  Parameters
#  |  ----------
#  |  missing_values : number, string, np.nan (default) or None
#  |      The placeholder for the missing values. All occurrences of
#  |      `missing_values` will be imputed.
#  |
#  |  strategy : string, optional (default="mean")
#  |      The imputation strategy.
#  |
#  |      - If "mean", then replace missing values using the mean along
#  |        each column. Can only be used with numeric data.
#  |      - If "median", then replace missing values using the median along
#  |        each column. Can only be used with numeric data.
# ...

# %%
arr
# Out:
# array([[ 1.,  2.,  3., nan],
#        [ 2.,  5., nan,  5.],
#        [ 2., nan,  2.,  3.]])

# %%
arr = pd.DataFrame([[1, 2, 3, np.nan], [2, 5, np.nan, 5], 
               [2, np.nan, 2, 3], [1,2,3,4]])

# %%
arr.dropna()
# Out:
#    0    1    2    3
# 3  1  2.0  3.0  4.0
